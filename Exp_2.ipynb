# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
data = pd.read_csv('surgeryfile.csv')
data.head()
# Out:
#      bmi   Age  asa_status  baseline_cancer  baseline_charlson  baseline_cvd  \
# 0  19.31  59.2           1                1                  0             0
# 1  18.73  59.1           0                0                  0             0
# 2  21.85  59.0           0                0                  0             0
# 3  18.49  59.0           1                0                  1             0
# 4  19.70  59.0           1                0                  0             0
#
#    baseline_dementia  baseline_diabetes  baseline_digestive  \
# 0                  0                  0                   0
# 1                  0                  0                   0
# 2                  0                  0                   0
# 3                  0                  1                   1
# 4                  0                  0                   0
#
#    baseline_osteoart  ...  complication_rsi  dow  gender   hour  month  \
# ...

# %%
train_labels = data['complication']
train_samples = data.drop('complication',axis=1)

train_samples = preprocessing.normalize(train_samples)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_samples, train_labels, random_state=5)

train_labels = np.array(y_train)
train_samples = np.array(X_train)

# %%
# scaler = MinMaxScaler(feature_range=(0,1))
# scaled_train_samples = scaler.fit_transform((train_samples).reshape(-1,1))
# scaled_train_samples = scaled_train_samples.reshape(14635, 24)

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import binary_crossentropy
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(10, activation='sigmoid', input_shape=(24,)))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1, activation= 'sigmoid'))

# model = Sequential([
#     Dense(16, input_shape=(24,),activation ='relu'),
#     Dense(32, activation = 'relu'),
#     Dense(2,  activation = 'softmax')
# ])

# %%
# model.summary()

# %%
model.compile(Adam(lr=0.01),loss='binary_crossentropy',metrics = ['accuracy'])

# %%
model.fit(train_samples, train_labels, validation_split = 0.1, batch_size = 10, epochs = 100, shuffle = True, verbose =2)
# Out:
# Train on 9878 samples, validate on 1098 samples
# Epoch 1/100
#  - 3s - loss: 0.5321 - accuracy: 0.7543 - val_loss: 0.4714 - val_accuracy: 0.7778
# Epoch 2/100
#  - 3s - loss: 0.4819 - accuracy: 0.7779 - val_loss: 0.4579 - val_accuracy: 0.7878
# Epoch 3/100
#  - 2s - loss: 0.4733 - accuracy: 0.7829 - val_loss: 0.4541 - val_accuracy: 0.7914
# Epoch 4/100
#  - 2s - loss: 0.4698 - accuracy: 0.7868 - val_loss: 0.4536 - val_accuracy: 0.7905
# Epoch 5/100
#  - 2s - loss: 0.4669 - accuracy: 0.7852 - val_loss: 0.4453 - val_accuracy: 0.7914
# Epoch 6/100
#  - 2s - loss: 0.4640 - accuracy: 0.7883 - val_loss: 0.4415 - val_accuracy: 0.7987
# Epoch 7/100
#  - 2s - loss: 0.4611 - accuracy: 0.7867 - val_loss: 0.4432 - val_accuracy: 0.7969
# Epoch 8/100
#  - 2s - loss: 0.4571 - accuracy: 0.7889 - val_loss: 0.4370 - val_accuracy: 0.7969
# Epoch 9/100
#  - 2s - loss: 0.4540 - accuracy: 0.7891 - val_loss: 0.4280 - val_accuracy: 0.8024
# Epoch 10/100
# ...
